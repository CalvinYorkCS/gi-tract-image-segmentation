# %%
import pandas as pd
from PIL import Image
from pathlib import Path
import numpy as np

# %%
train_df = pd.read_csv("../input/train.csv")

# %%
train_df.head()
# Out:
#                          id        class segmentation
# 0  case123_day20_slice_0001  large_bowel          NaN
# 1  case123_day20_slice_0001  small_bowel          NaN
# 2  case123_day20_slice_0001      stomach          NaN
# 3  case123_day20_slice_0002  large_bowel          NaN
# 4  case123_day20_slice_0002  small_bowel          NaN

# %%
temp_id = train_df['id'][1375]
id_list = temp_id.split('_')
print(id_list)
# Out:
# ['case77', 'day20', 'slice', '0027']

# %%
folder = Path("../input/train/" + id_list[0] + "/" + id_list[0] + "_" + id_list[1] + "/scans")
print(folder)
# Out:
# ../input/train/case77/case77_day20/scans

# %%
folder = Path(f"../input/train/{id_list[0]}/{id_list[0]}_{id_list[1]}/scans")
path = next(folder.glob(f"slice_{id_list[3]}_*"), None)

if path:
    print(f"Match found: {path}")
else:
    print("No match found")
# Out:
# Match found: ../input/train/case77/case77_day20/scans/slice_0027_266_266_1.50_1.50.png

# %%
image = Image.open(path)
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=I;16 size=266x266>

# %%
image = np.array(image)
image = image.ravel()
image
# Out:
# array([0, 0, 0, ..., 0, 0, 0], shape=(70756,), dtype=uint16)
